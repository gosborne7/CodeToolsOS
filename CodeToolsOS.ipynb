# %%
# whoami

# clear --clear screen

# pwd --current working directory

# ls --list contents of directory/folder

# cd --change directory implementing by shell 

# mkdir --make directory

# touch --makes empty file if file exits opens it in write mode

# rmdir --deletes directory folder has to be empty

# rm --removes files or directories can delete non-empty directories

# open --opens files and directories

# cp --copies files and folders

# hd --prints first part of file

# tail --prints the last part of file

# man --manpage for command reference

# help --help for certain commands

# mv --move files around or rename

# date --prints out date

# 'redirecting standard output' > and >>

# cat --Concatenate files

# less --Good way to navigate a file 

# echo --repeats input to command line

# wc --word count bytes, lines

# | --pipes commands 

# sort --ascending, descending etc

# uniq --omits repeated lines

# Wget --download files

# !nvidia-smi --GPU info

# ~ --home directory, see expansions

# expansions --shell will expand out certain characters: ~, $PATH,

# diff --differences between two different files

# find --find files or folders

# grep --find text inside of files

# du --find the size of files and directories

# df --info on mounted file systems

# history --review past commands

# ps --processes running on computer

# top --information about processes

# kill --stop or kill processes

# killall --kill all processes, usess name of processes

# jobs, bg, and fg --running things in background or foreground 

# gzip --uses LZ77 to compress files

# gunzip --type of compression

# tar --used to create an archive

# nano --text editor

# alias --define our name for commands 

# xargs --take input from one command to arguments for another command

# ln --create links

# who --displays users logged into system at the same time

# su --switch user to allow for login as another user

# sudo --super user do

# passwd --change password

# chown --change owndership of file or directory

# understanding permissions --ls -l

# chmod --change permissions of a file
# Out:
# Wed Jun  8 21:20:19 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...
